# %% [markdown]
# <a href="https://colab.research.google.com/github/Shashanka-Rajashekar/Flipkart_grid_6.0/blob/main/flipkart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Task 1 and 2 Method 4**

# %%
# !pip install -q -U google-generativeai

# %%
# !pip install ipython
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 22.2 MB/s eta 0:00:00
# ...

# %%
import google.generativeai as genai
from IPython.display import Markdown

# %%
from google.colab import userdata
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

genai.configure(api_key=GOOGLE_API_KEY)

# %%
def predict_image_details(img):
  print('success')

# %%
# Choose a Gemini API model.
model = genai.GenerativeModel(model_name="gemini-1.5-pro-latest")

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d4164091-b179-445d-b7ca-7783b12037a7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d4164091-b179-445d-b7ca-7783b12037a7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import PIL.Image
img = PIL.Image.open('11-ocr.jpg')

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Load the image
img = Image.open('11-ocr.jpg')

# Display the image using matplotlib
plt.imshow(img)
plt.axis('off')  # Turn off axis labels
plt.show()

predicted_details = predict_image_details(img)
print(predicted_details)
# Out:
# The image shows a jar of instant coffee. Here's the information that can be extracted:
# Brand Name: Tata Consumer Products Limited.
# Product Name: Instant Coffee
# Net Weight: 45g
# MRP: Rs. 180/-
# Expiry Date: JUL/25
# Manufacturing Date: FEB/24
# Other Information:
# The jar contains a Method of Preparation section.
# There's a note indicating "Images for illustration purpose only."
# The manufacturer's address is listed as Kolkata.

# %% [markdown]
# # **Task 1 and 2 Method 1**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fc53477e-8c13-4d92-8252-7f6d7423ba97" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fc53477e-8c13-4d92-8252-7f6d7423ba97">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # **Task 4 Method 2**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9e252020-e35e-4a77-a9ab-67467fcd1320" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9e252020-e35e-4a77-a9ab-67467fcd1320">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import PIL.Image
img1 = PIL.Image.open('1-rapple.jpeg')
display(img1)
# Choose a Gemini API model.
model = genai.GenerativeModel(model_name="gemini-1.5-pro-latest")

# Prompt the model with text and the previously uploaded image.
response = model.generate_content([img1, "On a rate of 1 to 10 how fresh is the fruit/vegetable with 10 being fresh and 1 being not fresh.Just give me number."])

Markdown(">" + response.text)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=203x180>
# >1

# %%
img2 = PIL.Image.open('1-napple.jpeg')
display(img2)
# Prompt the model with text and the previously uploaded image.
response = model.predict_freshness(img2)
Markdown(">" + response.text)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=180x180>
# >10
